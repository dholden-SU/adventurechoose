# %%
player = input("Enter your character's name: ")
choice1 = input("Do you want to play %s (enter yes or no)?"%(player)).lower()
while choice1 == "no":
    print("Please play again")
    choice1 = input("Do you want to play %s (enter yes or no)?"%(player)).lower()
while choice1 != "no" and choice1 != "yes":
    print("Try again")
    choice1 = input("Do you want to play %s (enter yes or no)?"%(player)).lower()
if choice1 == "yes":
    print("Let your adventure begin. You now have a sword to use along your journey!")
    print("You come across a forked road with two identical paths.")
    choice2 = input("Do you want to go left or right? ").lower()
while choice2 != "left" and choice2 != "right":
    print("Try again")
    choice2 = input("Do you want to go left or right? ").lower()
if choice2 == "left":
    items={}
    item =("sword")
    items= items,item
    gc = 25
    sword_dm=15
    df=0
    hi=1
    # "A:[] ","B:[]","c:[]" tlak_action=input("pick 1:").lower()
    ch=1
    while (hi>0):
        print(player,", you have chosen to go left.")  
        print("you walk the left path. you see a village in the distance. As you approach and a man walks up to you" )
        print("???: Hello adventurer! welcome to my village I'm the Chief of this village! we have been expecting you ", player )
        print("A:[what do you mean expecting me???]"," B:[how do you know my name?]"," C:*Attack the Chief and take over the village*")
        tlak_action=input("pick 1:").lower()
        if (tlak_action == 'a'):
            
            print(player,": What do you mean expecting me!?!")
            print("Chief: there's no time. Take this, arm yourself and help us. They're coming!!! find me when your done")
            print("he puts 25 gold coins (G) in your hand and runs off...")
            print("A:[explore the village] ","B:[leave the village]")
            
            tlak_action=input("pick 1:").lower()
            if (tlak_action == 'a'):
                while True:
                    print("you find a village map and see 3 locations to buy supplies")
                    while True:
                        print("A: smithery, B: armory, C: potions brewery d:Town hall")
                        tlak_action=input("pick 1:").lower()
                        if (tlak_action == 'a'):
                                print("in the smitherey you see a merchant")
                                print("smith: Welcome to my shop stranger, feel free to look around.")
                                print("you look at all the items")
                                while True:
                                    print("A:  weak bow with 5 arrows 5g B: swordbuff gem flame 20G c:leave")
                                    print("you have %d G"%(gc))
                                    tlak_action=input("pick 1:").lower()
                                    if (tlak_action == 'a'):
                                        if gc>=5:
                                            gc= gc-5
                                            print("you purchase a bow and 5 arrows")
                                            arrows=5
                                            item =("bow")
                                            items= items,item
                                            bow_dm=10
                                        else:
                                            print("you dont have enough")
                                    elif (tlak_action == 'b'):
                                            if (gc>=20):
                                                gc=gc-20
                                                print("you purchase a flamegem")
                                                sword_dm=sword_dm+10
                                            else:
                                                print("you dont have enough")
                                    elif(tlak_action == 'c'):
                                            print("you leave the shop")
                                            break
                        elif (tlak_action == 'b'):
                            print("in the armory you see a merchant")
                            print("merchant: Welcome to my shop stranger, feel free to look around.")
                            print("you look at all the items")
                            while True:
                                print("A: light leather underarmer 10df 5G B: heavy metal overarmer 20 c:leave")
                                print("you have %d G"%(gc))
                                tlak_action=input("pick 1:").lower()
                                if (tlak_action == 'a'):                    
                                    if gc>=5:
                                        gc= gc-5
                                        print("you purchased light leather underarmer")
                                        df=df+10
                                        item =("leverarmeru")
                                        items= items,item
                                    else:
                                         print("you dont have enough")
                                                #flame gem
                                elif (tlak_action == 'b'):
                                    if (gc>=20):
                                        gc=gc-20
                                        print("you purchase metal armer")
                                        df=df+25
                                        item =("mettlearmer")
                                        items= items,item
                                    else:
                                        print("you dont have enough")
                                elif(tlak_action == 'c'):
                                    print("you leave the shop")
                                    break
                        elif (tlak_action == 'c'):
                            print("in the potions brewery you see a merchant")
                            print("merchant: Welcome to my shop stranger, feel free to look around.")
                            print("you look at all the items")
                            while True:
                                print("A: moonshard potion 5G B: soul potion 20G c:leave")
                                print("you have %d G"%(gc))
                                tlak_action=input("pick 1:").lower()
                                if (tlak_action == 'a'):
                                    if gc>=5:
                                        gc= gc-5
                                        print("you purchased moonshard potion")
                                        item =("moonshardpotion")
                                        items= items,item
                                    else:
                                        print("you dont have enough")
                                                #flame gem
                                elif (tlak_action == 'b'):
                                    if (gc>=20):
                                        gc=gc-20
                                        print("you purchase soul potion")
                                        item =("solepotion")
                                        items= items,item
                                    else:
                                        print("you dont have enough")
                                elif(tlak_action == 'c'):
                                    print("you leave the shop")
                                    break
                        elif (tlak_action == 'd'):
                            print("TO TOWN HALL!! here you will meet the Chief")
                            print("as you enter town hall the Chief sees you")
                            print ("Chief: ah there you are so here's a horse now go to that oasis I will explain everything when I'm there")
                            print("Chief: but if something happens you must find the floating island and defeat the dragon!")
                            print("he points to a small oasis in the distance you can see mangos...MANGOS!!!")
                            print("A: *go* B: [what i dont even know you!]")
                            tlak_action=input("pick 1:").lower()
                            if (tlak_action == 'a'):
                                print("you go out on your horse")
                                print("while you're waiting the village gets hit by a huge fire ball and is destroyed")
                                print("you continue to search for the floating island to defeat some dragon!")
                                print("on your way a troll blocks your path")
                                print("A:fight b: run C:pay 2,000g")
                                tlak_action=input("pick 1:").lower()
                                if (tlak_action == 'a'):
                                    print("you win the troll is now dead")
                                    gc=gc+20
                                    print("you find 20G on the dead troll and a cooked steak")
                                    print("you continue to the floating island")
                                    print("when you jump on to the island from a near by cliff")
                                    print("???:hello?")
                                    print("a small white dragon looks at you with a hopeful glance")
                                    print("dragon: Oh! h-hello...c-could you h-help me?")
                                    print("dragon: I've been stuck here for months and I think my mother is not coming back.")
                                    print("you remember the cooked steak from the dead troll")
                                    print("A:*kill her* B:*help hear*")
                                    tlak_action=input("pick 1:").lower()
                                    if (tlak_action == 'a'):
                                        print("you unsheathe your sword")
                                        print("dragon looks scared")
                                        print("dragon: w-what are you donig... p-please D-DONT!")
                                        print("you walk towards the dragon she starts crying and shaking")
                                        print("dragon: SOMEBODY ANYBODY PLEASE HELP!")
                                        print(player,": hold still it will all be over soon")
                                        print("she curls up into a ball")
                                        print("dragon: p-please.")
                                        print("you chop off her head and put it into your bag")
                                        print("the cold dead lifeless body is splattering blood everywhere")
                                        print("to be continued")
                                        break
                                        break
                                        break
                                        hi=-1
                                        while True:
                                            gc=gc
                                    elif (tlak_action == 'b'):
                                        print("you take the steak out of your bag and walk towards her")
                                        print("dragon: t-thank you")
                                        print("you put the steak near her mouth she takes a bite")
                                        print("you sit down next to her she puts her claw on your leg")
                                        print("she moves closer, the warmth she has is welcoming")
                                        print("when she finishes the steak she snuggles up on you and licks your face")
                                        print("dragon whispers: Thank you.")
                                        print("she falls asleep on you")
                                        print("you grow tired, falling asleep in the warm embrace")
                                        print("to be continued")
                                        break
                                        break
                                        break
                                        hi=-1
                                        while True:
                                            gc=gc
                                elif (tlak_action == 'b'):
                                    print("the troll jumps on you and then eats you")
                                    print ("you have died your story ends here")
                                    break
                                    break
                                    break
                                    hi=-1
                                    while True:
                                        gc=gc
                                elif (tlak_action == 'c'):
                                    print("the troll jumps on you and then eats you")
                                    print ("you have died your story ends here")
                                    break
                                    break
                                    break
                                    hi=-1
                                    while True:
                                        gc=gc
                            elif (tlak_action == 'b'):
                                print(player,": what I dont even know you!")
                                print("Chief: I will explain everthing to you at the oasis.")
                                print(player,": NO I need to know what is going on right now or I'm not helping!")
                                print("Chief: fine, fine. we have reason to believe that the gods have sent us a warrior-")
                                print("- you. you're here to help us defeat all the evil forces of this world and.....")
                                print("the village gets hit by a huge fire ball and is destroyed with you in it")
                                print ("you have died your story ends here")
                                break
                                break
                                break
                                hi=-1
                                while True:
                                    gc=gc
                        else:
                            print("nope")
                        #break
                    break
                            
                    
            elif(tlak_action == 'b'):
                print("the gaurds see you and mistake you for a thief they attack you and kill you")
                print("you are dead your story ends here") 
                break
                while True:
                    gc=gc
        elif (tlak_action == 'b'):
            print(player,": how do you know my name?")
            print("Chief: there's no time. Take this, arm yourself and help us. They're coming!!! Find me when your done")
            print("he puts 25 gold coins (G) in your hand and runs off...")
            print("A:[explore the village] ","B:[leave the village]")
            
            tlak_action=input("pick 1:").lower()
            if (tlak_action == 'a'):
                while True:
                    print("you find a village map and see 3 locations to buy supplies")
                    while True:
                        print("A: smithery, B: armory, C: potions brewery d:Town hall")
                        tlak_action=input("pick 1:").lower()
                        if (tlak_action == 'a'):
                                print("in the smitherey you see a merchant")
                                print("smith: Welcome to my shop stranger, feel free to look around.")
                                print("you look at all the items")
                                while True:
                                    print("A:  weak bow with 5 arrows 5g B: swordbuff gem flame 20G c:leave")
                                    print("you have %d G"%(gc))
                                    tlak_action=input("pick 1:").lower()
                                    if (tlak_action == 'a'):
                                        if gc>=5:
                                            gc= gc-5
                                            print("you purchase a bow and 5 arrows")
                                            arrows=5
                                            item =("bow")
                                            items= items,item
                                            bow_dm=10
                                        else:
                                            print("you dont have enough")
                                    elif (tlak_action == 'b'):
                                            if (gc>=20):
                                                gc=gc-20
                                                print("you purchase a flamegem")
                                                sword_dm=sword_dm+10
                                            else:
                                                print("you dont have enough")
                                    elif(tlak_action == 'c'):
                                            print("you leave the shop")
                                            break
                        elif (tlak_action == 'b'):
                            print("in the armory you see a merchant")
                            print("merchant: Welcome to my shop stranger, feel free to look around.")
                            print("you look at all the items")
                            while True:
                                print("A: light leather underarmer 10df 5G B: heavy metal overarmer 20 c:leave")
                                print("you have %d G"%(gc))
                                tlak_action=input("pick 1:").lower()
                                if (tlak_action == 'a'):                    
                                    if gc>=5:
                                        gc= gc-5
                                        print("you purchased light leather underarmer")
                                        df=df+10
                                        item =("leverarmeru")
                                        items= items,item
                                    else:
                                         print("you dont have enough")
                                                #flame gem
                                elif (tlak_action == 'b'):
                                    if (gc>=20):
                                        gc=gc-20
                                        print("you purchase metal armer")
                                        df=df+25
                                        item =("mettlearmer")
                                        items= items,item
                                    else:
                                        print("you dont have enough")
                                elif(tlak_action == 'c'):
                                    print("you leave the shop")
                                    break
                        elif (tlak_action == 'c'):
                            print("in the potions brewery you see a merchant")
                            print("merchant: Welcome to my shop stranger, feel free to look around.")
                            print("you look at all the items")
                            while True:
                                print("A: moonshard potion 5G B: soul potion 20G c:leave")
                                print("you have %d G"%(gc))
                                tlak_action=input("pick 1:").lower()
                                if (tlak_action == 'a'):
                                    if gc>=5:
                                        gc= gc-5
                                        print("you purchased moonshard potion")
                                        item =("moonshardpotion")
                                        items= items,item
                                    else:
                                        print("you dont have enough")
                                                #flame gem
                                elif (tlak_action == 'b'):
                                    if (gc>=20):
                                        gc=gc-20
                                        print("you purchase soul potion")
                                        item =("solepotion")
                                        items= items,item
                                    else:
                                        print("you dont have enough")
                                elif(tlak_action == 'c'):
                                    print("you leave the shop")
                                    break
                        elif (tlak_action == 'd'):
                            print("TO TOWN HALL!! here you will meet the Chief")
                            print("as you enter town hall the Chief sees you")
                            print ("Chief: ah there you are so here's a horse now go to that oasis I will explain everything when I'm there")
                            print("Chief: but if something happens you must find the floating island and defeat the dragon!")
                            print("he points to a small oasis in the distance you can see mangos...MANGOS!!!")
                            print("A: *go* B: [what i dont even know you!]")
                            tlak_action=input("pick 1:").lower()
                            if (tlak_action == 'a'):
                                print("you go out on your horse")
                                print("while you're waiting the village gets hit by a huge fire ball and is destroyed")
                                print("you continue to search for the floating island to defeat some dragon!")
                                print("on your way a troll blocks your path")
                                print("A:fight b: run C:pay 2,000g")
                                tlak_action=input("pick 1:").lower()
                                if (tlak_action == 'a'):
                                    print("you win the troll is now dead")
                                    gc=gc+20
                                    print("you find 20G on the dead troll and a cooked steak")
                                    print("you continue to the floating island")
                                    print("when you jump on to the island from a near by cliff")
                                    print("???:hello?")
                                    print("a small white dragon looks at you with a hopeful glance")
                                    print("dragon: Oh! h-hello...c-could you h-help me?")
                                    print("dragon: I've been stuck here for months and I think my mother is not coming back.")
                                    print("you remember the cooked steak from the dead troll")
                                    print("A:*kill her* B:*help hear*")
                                    tlak_action=input("pick 1:").lower()
                                    if (tlak_action == 'a'):
                                        print("you unsheathe your sword")
                                        print("dragon looks scared")
                                        print("dragon: w-what are you donig... p-please D-DONT!")
                                        print("you walk towards the dragon she starts crying and shaking")
                                        print("dragon: SOMEBODY ANYBODY PLEASE HELP!")
                                        print(player,": hold still it will all be over soon")
                                        print("she curls up into a ball")
                                        print("dragon: p-please.")
                                        print("you chop off her head and put it into your bag")
                                        print("the cold dead lifeless body is splattering blood everywhere")
                                        print("to be continued")
                                        break
                                        break
                                        break
                                        hi=-1
                                        while True:
                                            gc=gc
                                    elif (tlak_action == 'b'):
                                        print("you take the steak out of your bag and walk towards her")
                                        print("dragon: t-thank you")
                                        print("you put the steak near her mouth she takes a bite")
                                        print("you sit down next to her she puts her claw on your leg")
                                        print("she moves closer, the warmth she has is welcoming")
                                        print("when she finishes the steak she snuggles up on you and licks your face")
                                        print("dragon whispers: Thank you.")
                                        print("she falls asleep on you")
                                        print("you grow tired, falling asleep in the warm embrace")
                                        print("to be continued")
                                        break
                                        break
                                        break
                                        hi=-1
                                        while True:
                                            gc=gc
                                elif (tlak_action == 'b'):
                                    print("the troll jumps on you and then eats you")
                                    print ("you have died your story ends here")
                                    break
                                    break
                                    break
                                    hi=-1
                                    while True:
                                        gc=gc
                                elif (tlak_action == 'c'):
                                    print("the troll jumps on you and then eats you")
                                    print ("you have died your story ends here")
                                    break
                                    break
                                    break
                                    hi=-1
                                    while True:
                                        gc=gc
                            elif (tlak_action == 'b'):
                                print(player,": what I dont even know you!")
                                print("Chief: I will explain everthing to you at the oasis.")
                                print(player,": NO I need to know what is going on right now or I'm not helping!")
                                print("Chief: fine, fine. we have reason to believe that the gods have sent us a warrior-")
                                print("- you. you're here to help us defeat all the evil forces of this world and.....")
                                print("the village gets hit by a huge fire ball and is destroyed with you in it")
                                print ("you have died your story ends here")
                                break
                                break
                                break
                                hi=-1
                                while True:
                                    gc=gc
                        else:
                            print("nope")
                        #break
                    break
                            
            
                            
                    
            elif(tlak_action == 'b'):
                print("the gaurds see you and mistake you for a thief they attack you and kill you")
                print("you are dead your story ends here") 
                break
                while True:
                    gc=gc
        elif (tlak_action == 'c'):
            print("you take your sword and impale the Chief he falls to his knees")
            print("Chief: w-w--why you... now they....will come...y-YOU!")
            print("YOU KILLED THE CHIEF! you have gained control of the village. You take 25 gold round things from the Chief's dead body.")
            print("you see the villagers ran all over in a panic")
            print("you are then surounded by the village gaurds before you can react they attack, killing you!")
            print ("you are now dead your story ends here.")
            break
        else:
            print("time warp")
if choice2 == "right":
    print(player,", you have chosen to go right.")
    print("what no go left!")
# Out:
# Enter your character's name: q
# Do you want to play q (enter yes or no)?yes
# Let your adventure begin. You now have a sword to use along your journey!
# You come across a forked road with two identical paths.
# Do you want to go left or right? left
# q , you have chosen to go left.
# you walk the left path. you see a village in the distance. As you approach and a man walks up to you
# ???: Hello adventurer! welcome to my village I'm the Chief of this village! we have been expecting you  q
# A:[what do you mean expecting me???]  B:[how do you know my name?]  C:*Attack the Chief and take over the village*
# pick 1:a
# q : What do you mean expecting me!?!
# Chief: there's no time. Take this, arm yourself and help us. They're coming!!! find me when your done
# he puts 25 gold coins (G) in your hand and runs off...
# A:[explore the village]  B:[leave the village]
# pick 1:a
# you find a village map and see 3 locations to buy supplies
# A: smithery, B: armory, C: potions brewery d:Town hall
# pick 1:a
# in the smitherey you see a merchant
# smith: Welcome to my shop stranger, feel free to look around.
# you look at all the items
# A:  weak bow with 5 arrows 5g B: swordbuff gem flame 20G c:leave
# you have 25 G
# pick 1:a
# you purchase a bow and 5 arrows
# A:  weak bow with 5 arrows 5g B: swordbuff gem flame 20G c:leave
# you have 20 G
# pick 1:c
# you leave the shop
# A: smithery, B: armory, C: potions brewery d:Town hall
# pick 1:b
# in the armory you see a merchant
# merchant: Welcome to my shop stranger, feel free to look around.
# you look at all the items
# A: light leather underarmer 10df 5G B: heavy metal overarmer 20 c:leave
# you have 20 G
# pick 1:c
# you leave the shop
# A: smithery, B: armory, C: potions brewery d:Town hall
# pick 1:c
# in the potions brewery you see a merchant
# merchant: Welcome to my shop stranger, feel free to look around.
# you look at all the items
# A: moonshard potion 5G B: soul potion 20G c:leave
# you have 20 G
# pick 1:c
# you leave the shop
# A: smithery, B: armory, C: potions brewery d:Town hall
# pick 1:b
# in the armory you see a merchant
# merchant: Welcome to my shop stranger, feel free to look around.
# you look at all the items
# A: light leather underarmer 10df 5G B: heavy metal overarmer 20 c:leave
# you have 20 G
# pick 1:iugfdfgh
# A: light leather underarmer 10df 5G B: heavy metal overarmer 20 c:leave
# you have 20 G
# pick 1:ytrdfghuytg
# A: light leather underarmer 10df 5G B: heavy metal overarmer 20 c:leave
# you have 20 G
# pick 1:m,lmnfghjkjhgfr
# A: light leather underarmer 10df 5G B: heavy metal overarmer 20 c:leave
# you have 20 G
# pick 1:y9ojyt6yuklkuyuilkyuiht
# A: light leather underarmer 10df 5G B: heavy metal overarmer 20 c:leave
# you have 20 G
# pick 1:6uijhgtyuijhgtyuj
# A: light leather underarmer 10df 5G B: heavy metal overarmer 20 c:leave
# you have 20 G
# pick 1:hgtyuhghy7uijhyu
# A: light leather underarmer 10df 5G B: heavy metal overarmer 20 c:leave
# you have 20 G
# pick 1:ijhgyuijhyuijhy
# A: light leather underarmer 10df 5G B: heavy metal overarmer 20 c:leave
# you have 20 G
# pick 1:a
# you purchased light leather underarmer
# A: light leather underarmer 10df 5G B: heavy metal overarmer 20 c:leave
# you have 15 G
# pick 1:a
# you purchased light leather underarmer
# A: light leather underarmer 10df 5G B: heavy metal overarmer 20 c:leave
# you have 10 G
# pick 1:a
# you purchased light leather underarmer
# A: light leather underarmer 10df 5G B: heavy metal overarmer 20 c:leave
# you have 5 G
# pick 1:a
# you purchased light leather underarmer
# A: light leather underarmer 10df 5G B: heavy metal overarmer 20 c:leave
# you have 0 G
# pick 1:a
# you dont have enough
# A: light leather underarmer 10df 5G B: heavy metal overarmer 20 c:leave
# you have 0 G
# pick 1:a
# you dont have enough
# A: light leather underarmer 10df 5G B: heavy metal overarmer 20 c:leave
# you have 0 G
# pick 1:a
# you dont have enough
# A: light leather underarmer 10df 5G B: heavy metal overarmer 20 c:leave
# you have 0 G
# pick 1:c
# you leave the shop
# A: smithery, B: armory, C: potions brewery d:Town hall
# pick 1:d
# TO TOWN HALL!! here you will meet the Chief
# as you enter town hall the Chief sees you
# Chief: ah there you are so here's a horse now go to that oasis I will explain everything when I'm there
# Chief: but if something happens you must find the floating island and defeat the dragon!
# he points to a small oasis in the distance you can see mangos...MANGOS!!!
# A: *go* B: [what i dont even know you!]
# pick 1:b
# q : what I dont even know you!
# Chief: I will explain everthing to you at the oasis.
# q : NO I need to know what is going on right now or I'm not helping!
# Chief: fine, fine. we have reason to believe that the gods have sent us a warrior-
# - you. you're here to help us defeat all the evil forces of this world and.....
# the village gets hit by a huge fire ball and is destroyed with you in it
# you have died your story ends here
# q , you have chosen to go left.
# you walk the left path. you see a village in the distance. As you approach and a man walks up to you
# ???: Hello adventurer! welcome to my village I'm the Chief of this village! we have been expecting you  q
# A:[what do you mean expecting me???]  B:[how do you know my name?]  C:*Attack the Chief and take over the village*
# pick 1:c
# you take your sword and impale the Chief he falls to his knees
# Chief: w-w--why you... now they....will come...y-YOU!
# YOU KILLED THE CHIEF! you have gained control of the village. You take 25 gold round things from the Chief's dead body.
# you see the villagers ran all over in a panic
# you are then surounded by the village gaurds before you can react they attack, killing you!
# you are now dead your story ends here.

# %%
try:
    string= input("enter words: ").lower()
    f={}
    for i in string:

        f[i]=f.get(0,0)+1
    print("your items",f)
except:
    print("AAAAAAAAAAAAAAAAA")
# Out:
# enter words: sword
# your items {'s': 1, 'w': 1, 'o': 1, 'r': 1, 'd': 1}

# %%
items={}
item =input("Enter item: ")
items= items,item
item =input("Enter item: ")
items= sitems,item
print(items)
