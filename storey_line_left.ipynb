# %%
def storylineleft():player = input("Enter your character's name: ")
choice1 = input("Do you want to play %s (enter yes or no)?"%(player)).lower()
while choice1 == "no":
    print("Please play again")
    choice1 = input("Do you want to play %s (enter yes or no)?"%(player)).lower()
while choice1 != "no" and choice1 != "yes":
    print("Try again")
    choice1 = input("Do you want to play %s (enter yes or no)?"%(player)).lower()
if choice1 == "yes":
    print("Let your adventure begin. You now have a sword to use along your journey!")
    print("You come across a forked road with two identical paths.")
    choice2 = input("Do you want to go left or right? ").lower()
while choice2 != "left" and choice2 != "right":
    print("Try again")
    choice2 = input("Do you want to go left or right? ").lower()
if choice2 == "left":
    items={}
    item =("sword")
    items= items,item
    gc = 25
    sword_dm=15
    df=0
    hi=1
    # "A:[] ","B:[]","c:[]" tlak_action=input("pick 1:").lower()
    ch=1
    while (hi>0):
        print(player,", you have chosen to go left.")  
        print("you walk the left path. you see a village in the distance as you approach and a man walks up to you" )
        print("???: Hello adventurer! welcome to my village im the Chief of this village! we have been expecting you ", player )
        print("A:[what do you mean expecting me???]"," B:[how do you know my name?]"," C:*Attack the Chief and take over the village*")
        tlak_action=input("pick 1:").lower()
        if (tlak_action == 'a'):
            
            print(player,": What do you mean expecting me!?!")
            print("chief: there's no time. Take this, arm yourself and help us. They're coming!!! find me when your done")
            print("he puts 25 gold coins (G) in your hand and runs off...")
            print("A:[explore the village] ","B:[leave the village]")
            
            tlak_action=input("pick 1:").lower()
            if (tlak_action == 'a'):
                while True:
                    print("you find a village map and see 3 locations to buy supplies")
                    while True:
                        print("A: smithery, B: armory, C: potions brewery d:Town hall")
                        tlak_action=input("pick 1:").lower()
                        if (tlak_action == 'a'):
                                print("in the smitherey you see a merchant")
                                print("smith: Welcome to my shop stranger, feel free to look around.")
                                print("you look at all the items")
                                while True:
                                    print("A:  weak bow with 5 arrows 5g B: swordbuff gem flame 20G c:leave")
                                    print("you have %d G"%(gc))
                                    tlak_action=input("pick 1:").lower()
                                    if (tlak_action == 'a'):
                                        if gc>=5:
                                            gc= gc-5
                                            print("you purchase a bow and 5 arrows")
                                            arrows=5
                                            item =("bow")
                                            items= items,item
                                            bow_dm=10
                                        else:
                                            print("you dont have enough")
                                    elif (tlak_action == 'b'):
                                            if (gc>=20):
                                                gc=gc-20
                                                print("you purchase a flamegem")
                                                sword_dm=sword_dm+10
                                            else:
                                                print("you dont have enough")
                                    elif(tlak_action == 'c'):
                                            print("you leave the shop")
                                            break
                        elif (tlak_action == 'b'):
                            print("in the armory you see a merchant")
                            print("merchant: Welcome to my shop stranger, feel free to look around.")
                            print("you look at all the items")
                            while True:
                                print("A: light leather underarmer 10df 5G B: heavy metal overarmer 20 c:leave")
                                print("you have %d G"%(gc))
                                tlak_action=input("pick 1:").lower()
                                if (tlak_action == 'a'):                    
                                    if gc>=5:
                                        gc= gc-5
                                        print("you purchased light leather underarmer")
                                        df=df+10
                                        item =("leverarmeru")
                                        items= items,item
                                    else:
                                         print("you dont have enough")
                                                #flame gem
                                elif (tlak_action == 'b'):
                                    if (gc>=20):
                                        gc=gc-20
                                        print("you purchase metal armer")
                                        df=df+25
                                        item =("mettlearmer")
                                        items= items,item
                                    else:
                                        print("you dont have enough")
                                elif(tlak_action == 'c'):
                                    print("you leave the shop")
                                    break
                        elif (tlak_action == 'c'):
                            print("in the potions brewery you see a merchant")
                            print("merchant: Welcome to my shop stranger, feel free to look around.")
                            print("you look at all the items")
                            while True:
                                print("A: moonshard potion 5G B: soul potion 20G c:leave")
                                print("you have %d G"%(gc))
                                tlak_action=input("pick 1:").lower()
                                if (tlak_action == 'a'):
                                    if gc>=5:
                                        gc= gc-5
                                        print("you purchased moonshard potion")
                                        item =("moonshardpotion")
                                        items= items,item
                                    else:
                                        print("you dont have enough")
                                                #flame gem
                                elif (tlak_action == 'b'):
                                    if (gc>=20):
                                        gc=gc-20
                                        print("you purchase soul potion")
                                        item =("solepotion")
                                        items= items,item
                                    else:
                                        print("you dont have enough")
                                elif(tlak_action == 'c'):
                                    print("you leave the shop")
                                    break
                        elif (tlak_action == 'd'):
                            print("TO TOWN HALL!! here you will meet the chief")
                            print("as you enter town hall the chief sees you")
                            print ("chief: ah there you are so here's a horse now go to that oasis I will explain everything when im there")
                            print("chief: but if something happens you must find the floating island and defeat the dragon!")
                            print("he points to a small oasis in the distance you can see mangos...MANGOS!!!")
                            print("A: *go* B: [what i dont even know you!]")
                            tlak_action=input("pick 1:").lower()
                            if (tlak_action == 'a'):
                                print("you go out on your horse")
                                print("while you're waiting the village gets hit by a huge fire ball and is destroyed")
                                print("you continue to search for the floating island to defeat some dragon!")
                                print("on your way a troll blocks your path")
                                print("A:fight b: run C:pay 2,000g")
                                tlak_action=input("pick 1:").lower()
                                if (tlak_action == 'a'):
                                    print("you win the troll is now dead")
                                    gc=gc+20
                                    print("you find 20G on the dead troll and a cooked steak")
                                    print("you continue to the floating island")
                                    print("when you jump on to the island from a near by cliff")
                                    print("???:hello?")
                                    print("a small white dragon looks at you with a hopeful glance")
                                    print("dragon: Oh! h-hello...c-could you h-help me?")
                                    print("dragon: I've been stuck here for months and i think my mother is not coming back.")
                                    print("you remeber the cooked steak from the dead troll")
                                    print("A:*kill her* B:*help hear*")
                                    tlak_action=input("pick 1:").lower()
                                    if (tlak_action == 'a'):
                                        print("you unsheathe your sword")
                                        print("dragon looks scared")
                                        print("dragon: w-what are you doing... p-please D-DONT!")
                                        print("you walk towards the dragon she starts crying and shaking")
                                        print("dragon: SOMEBODY ANYBODY PLEASE HELP!")
                                        print(player,": hold still it will all be over soon")
                                        print("she curls up into a ball")
                                        print("dragon: p-please.")
                                        print("you chop off her head and put it into your bag")
                                        print("the cold dead lifeless body is splattering blood everywhere")
                                        print("to be continued")
                                        break
                                        break
                                        break
                                        hi=-1
                                        while True:
                                            gc=gc
                                    elif (tlak_action == 'b'):
                                        print("you take the steak out of your bag and walk towards her")
                                        print("dragon: t-thank you")
                                        print("you put the steak near her mouth she takes a bite")
                                        print("you sit down next to her she puts her claw on your leg")
                                        print("she moves closer the warmth she has is welcoming")
                                        print("when she finishies the steak she snuggles up on you and licks your face")
                                        print("dragon whispers in your ear: Thank you.")
                                        print("she falls asleep on top of you")
                                        print("you grow tired, falling asleep in the warm embrace")
                                        print("to be continued")
                                        break
                                        break
                                        break
                                        hi=-1
                                        while True:
                                            gc=gc
                                elif (tlak_action == 'b'):
                                    print("the troll jumps on you and then eats you")
                                    print ("you have died your story ends here")
                                    break
                                    break
                                    break
                                    hi=-1
                                    while True:
                                        gc=gc
                                elif (tlak_action == 'c'):
                                    print("the troll jumps on you and then eats you")
                                    print ("you have died your story ends here")
                                    break
                                    break
                                    break
                                    hi=-1
                                    while True:
                                        gc=gc
                            elif (tlak_action == 'b'):
                                print(player,": what i dont even know you!")
                                print("chief: I will explain everthing to you at the oasis.")
                                print(player,": NO i need to know what is going on right now or im not helping!")
                                print("chief: Fine, fine we have reason to believe that the gods have sent us a warrior-")
                                print("- you. You're here to help us defeat all the evil forces of this world and.....")
                                print("the village gets hit by a huge fire ball and is destroyed with you in it")
                                print ("you have died your story ends here")
                                break
                                break
                                break
                                hi=-1
                                while True:
                                    gc=gc
                        else:
                            print("nope")
                        
                    break
                            
                    
            elif(tlak_action == 'b'):
                print("the gaurds see you and mistake you for a thief they attack you and kill you")
                print("you are dead your story ends here")
    print("")
# Out:
#   File "<tokenize>", line 35
#     break
#     ^
# IndentationError: unindent does not match any outer indentation level

# %%
player = input("Enter your character's name: ")
choice1 = input("Do you want to play %s (enter yes or no)?"%(player)).lower()
while choice1 == "no":
    print("Please play again")
    choice1 = input("Do you want to play %s (enter yes or no)?"%(player)).lower()
while choice1 != "no" and choice1 != "yes":
    print("Try again")
    choice1 = input("Do you want to play %s (enter yes or no)?"%(player)).lower()
if choice1 == "yes":
    print("Let your adventure begin. You now have a sword to use along your journey!")
    print("You come across a forked road with two identical paths.")
    choice2 = input("Do you want to go left or right? ").lower()
while choice2 != "left" and choice2 != "right":
    print("Try again")
    choice2 = input("Do you want to go left or right? ").lower()
if choice2 == "left":
    items={}
    item =("sword")
    items= items,item
    gc = 25
    sword_dm=15
    df=0
    hi=1
    # "A:[] ","B:[]","c:[]" tlak_action=input("pick 1:").lower()
    ch=1
    while (hi>0):
        print(player,", you have chosen to go left.")  
        print("you walk the left path. you see a village in the distance as you approach and a man walks up to you" )
        print("???: Hello adventurer! welcome to my village im the Chief of this village! we have been expecting you ", player )
        print("A:[what do you mean expecting me???]"," B:[how do you know my name?]"," C:*Attack the Chief and take over the village*")
        tlak_action=input("pick 1:").lower()
        if (tlak_action == 'a'):
            
            print(player,": What do you mean expecting me!?!")
            print("chief: there's no time. Take this, arm yourself and help us. They're coming!!! find me when your done")
            print("he puts 25 gold coins (G) in your hand and runs off...")
            print("A:[explore the village] ","B:[leave the village]")
            
            tlak_action=input("pick 1:").lower()
            if (tlak_action == 'a'):
                while True:
                    print("you find a village map and see 3 locations to buy supplies")
                    while True:
                        print("A: smithery, B: armory, C: potions brewery d:Town hall")
                        tlak_action=input("pick 1:").lower()
                        if (tlak_action == 'a'):
                                print("in the smitherey you see a merchant")
                                print("smith: Welcome to my shop stranger, feel free to look around.")
                                print("you look at all the items")
                                while True:
                                    print("A:  weak bow with 5 arrows 5g B: swordbuff gem flame 20G c:leave")
                                    print("you have %d G"%(gc))
                                    tlak_action=input("pick 1:").lower()
                                    if (tlak_action == 'a'):
                                        if gc>=5:
                                            gc= gc-5
                                            print("you purchase a bow and 5 arrows")
                                            arrows=5
                                            item =("bow")
                                            items= items,item
                                            bow_dm=10
                                        else:
                                            print("you dont have enough")
                                    elif (tlak_action == 'b'):
                                            if (gc>=20):
                                                gc=gc-20
                                                print("you purchase a flamegem")
                                                sword_dm=sword_dm+10
                                            else:
                                                print("you dont have enough")
                                    elif(tlak_action == 'c'):
                                            print("you leave the shop")
                                            break
                        elif (tlak_action == 'b'):
                            print("in the armory you see a merchant")
                            print("merchant: Welcome to my shop stranger, feel free to look around.")
                            print("you look at all the items")
                            while True:
                                print("A: light leather underarmer 10df 5G B: heavy metal overarmer 20 c:leave")
                                print("you have %d G"%(gc))
                                tlak_action=input("pick 1:").lower()
                                if (tlak_action == 'a'):                    
                                    if gc>=5:
                                        gc= gc-5
                                        print("you purchased light leather underarmer")
                                        df=df+10
                                        item =("leverarmeru")
                                        items= items,item
                                    else:
                                         print("you dont have enough")
                                                #flame gem
                                elif (tlak_action == 'b'):
                                    if (gc>=20):
                                        gc=gc-20
                                        print("you purchase metal armer")
                                        df=df+25
                                        item =("mettlearmer")
                                        items= items,item
                                    else:
                                        print("you dont have enough")
                                elif(tlak_action == 'c'):
                                    print("you leave the shop")
                                    break
                        elif (tlak_action == 'c'):
                            print("in the potions brewery you see a merchant")
                            print("merchant: Welcome to my shop stranger, feel free to look around.")
                            print("you look at all the items")
                            while True:
                                print("A: moonshard potion 5G B: soul potion 20G c:leave")
                                print("you have %d G"%(gc))
                                tlak_action=input("pick 1:").lower()
                                if (tlak_action == 'a'):
                                    if gc>=5:
                                        gc= gc-5
                                        print("you purchased moonshard potion")
                                        item =("moonshardpotion")
                                        items= items,item
                                    else:
                                        print("you dont have enough")
                                                #flame gem
                                elif (tlak_action == 'b'):
                                    if (gc>=20):
                                        gc=gc-20
                                        print("you purches soul potion")
                                        item =("solepotion")
                                        items= items,item
                                    else:
                                        print("you dont have enough")
                                elif(tlak_action == 'c'):
                                    print("you leave the shop")
                                    break
                        elif (tlak_action == 'd'):
                            print("TO TOWN HALL!! here you will meet the chief")
                            print("as you enter town hall the chief sees you")
                            print ("chief: ah there you are so here's a horse now go to that oasis I will explain everything when im there")
                            print("chief: but if something happens you must find the floting island and defeat the dragon!")
                            print("he points to a small oasis in the distance you can see mangos...MANGOS!!!")
                            print("A: *go* B: [what i dont even know you!]")
                            tlak_action=input("pick 1:").lower()
                            if (tlak_action == 'a'):
                                print("you go out on your horse")
                                print("while your wateing the village gets hit by a huge fire ball and is destroyed")
                                print("you continu to search for the floting island to defeat some dragon!")
                                print("an your way a trol blocks your path")
                                print("A:fight b: run C:pay 20000g")
                                tlak_action=input("pick 1:").lower()
                                if (tlak_action == 'a'):
                                    print("you win the trol is now dead")
                                    gc=gc+20
                                    print("you find 20G on the dead trool and a cooked steak")
                                    print("you continu to the floting island")
                                    print("when you jump on to the island from a near by cliff")
                                    print("???:hello?")
                                    print("a smll white dragon looks at you with a hopful glance")
                                    print("dragon: O! h-hello...c-could you h-help me?")
                                    print("dragon: Iv ben stuck hear for months and i think my mother isint comming back.")
                                    print("you rember the cookrd steak from th dead trool")
                                    print("A:*kill her* B:*help hear*")
                                    tlak_action=input("pick 1:").lower()
                                    if (tlak_action == 'a'):
                                        print("you unsheav your sword")
                                        print("dragon looks skared")
                                        print("dragon: w-what ar you doonig... p-pleas D-DONT!")
                                        print("you wak tords the dracon she starts crying and shaking")
                                        print("dragon: SOMBODEY ENEYBODY PLEAS HELP!")
                                        print(player,": hold still it will all be over soon")
                                        print("she curls up into a ball")
                                        print("dragon: p-pleas.")
                                        print("you chop off her head and put it into your bag")
                                        print("the cold dead lifles boddy is ")
                                        print("to be continued")
                                        break
                                        break
                                        break
                                        hi=-1
                                        while True:
                                            gc=gc
                                    elif (tlak_action == 'b'):
                                        print("you take the stake out of your bag and walk twords her")
                                        print("dragon: t-thank you")
                                        print("you put the stake near  her mouth she taks a bite")
                                        print("you sit down nexto her she puts her claw on your leag")
                                        print("she moves closer the wormth she has is welcoming")
                                        print("when she finishies the stake she snuggl up on you and licks your face")
                                        print("dragon wispers in your ear: Thak you.")
                                        print("she falls asleep on top of you")
                                        print("you gro tired falling asleep tn the worm brace")
                                        print("to be continued")
                                        break
                                        break
                                        break
                                        hi=-1
                                        while True:
                                            gc=gc
                                elif (tlak_action == 'b'):
                                    print("the trool jumps on you and then eats you")
                                    print ("you have died your story ends hear")
                                    break
                                    break
                                    break
                                    hi=-1
                                    while True:
                                        gc=gc
                                elif (tlak_action == 'c'):
                                    print("the trool jumps on you and then eats you")
                                    print ("you have died your story ends hear")
                                    break
                                    break
                                    break
                                    hi=-1
                                    while True:
                                        gc=gc
                            elif (tlak_action == 'b'):
                                print(player,": what i dont even know you!")
                                print("chief: I will explain everthing to you at the oasis.")
                                print(player,": NO i need to know what is going on right now or im not helping!")
                                print("chief: fine, fine we have reason to believe that the gods have sent us a warrior-")
                                print("- you your here to help us defeat all the evil forces of this world and.....")
                                print("the village gets hit by a huge fire ball and is destroyed with you in it")
                                print ("you have died your story ends here")
                                break
                                break
                                break
                                hi=-1
                                while True:
                                    gc=gc
                        else:
                            print("nope")
                        
                    break
                            
                    
            elif(tlak_action == 'b'):
                print("the gaurds see you and mistake you for a thief they attack you and kill you")
                print("you are dead your story ends here") 
                break
                while True:
                    gc=gc
        elif (tlak_action == 'b'):
            print(player,": how do you know my name?")
            print("chief: there's no time. Take this, arm yourself and help us. They're coming!!! find me when your done")
            print("he puts 25 gold coins (G) in your hand and runs off...")
           print("A:[explore the village] ","B:[leave the village]")
            
            tlak_action=input("pick 1:").lower()
            if (tlak_action == 'a'):
                while True:
                    print("you find a village map and see 3 locations to buy supplies")
                    while True:
                        print("A: smithery, B: armory, C: potions brewery d:Town hall")
                        tlak_action=input("pick 1:").lower()
                        if (tlak_action == 'a'):
                                print("in the smitherey you see a merchant")
                                print("smith: Welcome to my shop stranger, feel free to look around.")
                                print("you look at all the items")
                                while True:
                                    print("A:  weak bow with 5 arrows 5g B: swordbuff gem flame 20G c:leave")
                                    print("you have %d G"%(gc))
                                    tlak_action=input("pick 1:").lower()
                                    if (tlak_action == 'a'):
                                        if gc>=5:
                                            gc= gc-5
                                            print("you purchase a bow and 5 arrows")
                                            arrows=5
                                            item =("bow")
                                            items= items,item
                                            bow_dm=10
                                        else:
                                            print("you dont have enough")
                                    elif (tlak_action == 'b'):
                                            if (gc>=20):
                                                gc=gc-20
                                                print("you purchase a flamegem")
                                                sword_dm=sword_dm+10
                                            else:
                                                print("you dont have enough")
                                    elif(tlak_action == 'c'):
                                            print("you leave the shop")
                                            break
                        elif (tlak_action == 'b'):
                            print("in the armory you see a merchant")
                            print("merchant: Welcome to my shop stranger, feel free to look around.")
                            print("you look at all the items")
                            while True:
                                print("A: light leather underarmer 10df 5G B: heavy metal overarmer 20 c:leave")
                                print("you have %d G"%(gc))
                                tlak_action=input("pick 1:").lower()
                                if (tlak_action == 'a'):                    
                                    if gc>=5:
                                        gc= gc-5
                                        print("you purchased light leather underarmer")
                                        df=df+10
                                        item =("leverarmeru")
                                        items= items,item
                                    else:
                                         print("you dont have enough")
                                                #flame gem
                                elif (tlak_action == 'b'):
                                    if (gc>=20):
                                        gc=gc-20
                                        print("you purchase metal armer")
                                        df=df+25
                                        item =("mettlearmer")
                                        items= items,item
                                    else:
                                        print("you dont have enough")
                                elif(tlak_action == 'c'):
                                    print("you leave the shop")
                                    break
                        elif (tlak_action == 'c'):
                            print("in the potions brewery you see a merchant")
                            print("merchant: Welcome to my shop stranger, feel free to look around.")
                            print("you look at all the items")
                            while True:
                                print("A: moonshard potion 5G B: soul potion 20G c:leave")
                                print("you have %d G"%(gc))
                                tlak_action=input("pick 1:").lower()
                                if (tlak_action == 'a'):
                                    if gc>=5:
                                        gc= gc-5
                                        print("you purchased moonshard potion")
                                        item =("moonshardpotion")
                                        items= items,item
                                    else:
                                        print("you dont have enough")
                                                #flame gem
                                elif (tlak_action == 'b'):
                                    if (gc>=20):
                                        gc=gc-20
                                        print("you purches soul potion")
                                        item =("solepotion")
                                        items= items,item
                                    else:
                                        print("you dont have enough")
                                elif(tlak_action == 'c'):
                                    print("you leave the shop")
                                    break
                        elif (tlak_action == 'd'):
                            print("TO TOWN HALL!! here you will meet the chief")
                            print("as you enter town hall the chief sees you")
                            print ("chief: ah there you are so here's a horse now go to that oasis I will explain everything when im there")
                            print("chief: but if something happens you must find the floting island and defeat the dragon!")
                            print("he points to a small oasis in the distance you can see mangos...MANGOS!!!")
                            print("A: *go* B: [what i dont even know you!]")
                            tlak_action=input("pick 1:").lower()
                            if (tlak_action == 'a'):
                                print("you go out on your horse")
                                print("while your wateing the village gets hit by a huge fire ball and is destroyed")
                                print("you continu to search for the floting island to defeat some dragon!")
                                print("an your way a trol blocks your path")
                                print("A:fight b: run C:pay 20000g")
                                tlak_action=input("pick 1:").lower()
                                if (tlak_action == 'a'):
                                    print("you win the trol is now dead")
                                    gc=gc+20
                                    print("you find 20G on the dead trool and a cooked steak")
                                    print("you continu to the floting island")
                                    print("when you jump on to the island from a near by cliff")
                                    print("???:hello?")
                                    print("a smll white dragon looks at you with a hopful glance")
                                    print("dragon: O! h-hello...c-could you h-help me?")
                                    print("dragon: Iv ben stuck hear for months and i think my mother isint comming back.")
                                    print("you rember the cookrd steak from th dead trool")
                                    print("A:*kill her* B:*help hear*")
                                    tlak_action=input("pick 1:").lower()
                                    if (tlak_action == 'a'):
                                        print("you unsheav your sword")
                                        print("dragon looks skared")
                                        print("dragon: w-what ar you doonig... p-pleas D-DONT!")
                                        print("you wak tords the dracon she starts crying and shaking")
                                        print("dragon: SOMBODEY ENEYBODY PLEAS HELP!")
                                        print(player,": hold still it will all be over soon")
                                        print("she curls up into a ball")
                                        print("dragon: p-pleas.")
                                        print("you chop off her head and put it into your bag")
                                        print("the cold dead lifles boddy is ")
                                        print("to be continued")
                                        break
                                        break
                                        break
                                        hi=-1
                                        while True:
                                            gc=gc
                                    elif (tlak_action == 'b'):
                                        print("you take the stake out of your bag and walk twords her")
                                        print("dragon: t-thank you")
                                        print("you put the stake near  her mouth she taks a bite")
                                        print("you sit down nexto her she puts her claw on your leag")
                                        print("she moves closer the wormth she has is welcoming")
                                        print("when she finishies the stake she snuggl up on you and licks your face")
                                        print("dragon wispers in your ear: Thak you.")
                                        print("she falls asleep on top of you")
                                        print("you gro tired falling asleep tn the worm brace")
                                        print("to be continued")
                                        break
                                        break
                                        break
                                        hi=-1
                                        while True:
                                            gc=gc
                                elif (tlak_action == 'b'):
                                    print("the trool jumps on you and then eats you")
                                    print ("you have died your story ends hear")
                                    break
                                    break
                                    break
                                    hi=-1
                                    while True:
                                        gc=gc
                                elif (tlak_action == 'c'):
                                    print("the trool jumps on you and then eats you")
                                    print ("you have died your story ends hear")
                                    break
                                    break
                                    break
                                    hi=-1
                                    while True:
                                        gc=gc
                            elif (tlak_action == 'b'):
                                print(player,": what i dont even know you!")
                                print("chief: I will explain everthing to you at the oasis.")
                                print(player,": NO i need to know what is going on right now or im not helping!")
                                print("chief: fine, fine we have reason to believe that the gods have sent us a warrior-")
                                print("- you your here to help us defeat all the evil forces of this world and.....")
                                print("the village gets hit by a huge fire ball and is destroyed with you in it")
                                print ("you have died your story ends here")
                                break
                                break
                                break
                                hi=-1
                                while True:
                                    gc=gc
                        else:
                            print("nope")
                        
                    break
                            
                    
            elif(tlak_action == 'b'):
                print("the gaurds see you and mistake you for a thief they attack you and kill you")
                print("you are dead your story ends here") 
                break
                while True:
                    gc=gc
        elif (tlak_action == 'c'):
            print("you take your sword and impale the chief he falls to his knees")
            print("chief: w-w--why you... now thay....will come...y-YOU!")
            print("YOU KILL THE CHIEF! you have gained control of the village 25 gold round things from the Chief.")
            print("you see the villagers raul all over in a panick")
            print("you ar then serounded by the village gards be for you can re act thay attck killing you!")
            print ("you ar now dead")
            break
        else:
            print("time worp")
if choice2 == "right":
    print(player,", you have chosen to go right.")
    print("what no go left!")
# Out:
# Enter your character's name: rcv12
# Do you want to play rcv12 (enter yes or no)?yes
# Let your adventure begin. You now have a sword to use along your journey!
# You come across a forked road with two identical paths.
# Do you want to go left or right? left
# rcv12 , you have chosen to go left.
# you walk the left path. you see a village in the distance as you approach and a man walks up to you
# ???: Hello adventurer! welcome to my village im the Chief of this village! we have been expecting you  rcv12
# A:[what do you mean expecting me???]  B:[how do you know my name?]  C:*Attack the Chief and take over the village*
# pick 1:b
# rcv12 : how do you know my name?
# chief: there's no time. Take this, arm yourself and help us. They're coming!!! find me when your done
# he puts 25 gold coins (G) in your hand and runs off...
# A:[explore the village]  B:[leave the village]
# pick 1:a
# you find a village map and see 3 locations to buy supplies
# A: smithery, B: armory, C: potions brewery d:Town hall
# pick 1:d
# TO TOWN HALL!! here you will meet the chief
# as you enter town hall the chief sees you
# chief: ah there you are so here's a horse now go to that oasis I will explain everything when im there
# chief: but if something happens you must find the floting island and defeat the dragon!
# he points to a small oasis in the distance you can see mangos...MANGOS!!!
# A: *go* B: [what i dont even know you!]
# pick 1:a
# you go out on your horse
# while your wateing the village gets hit by a huge fire ball and is destroyed
# you continu to search for the floting island to defeat some dragon!
# an your way a trol blocks your path
# A:fight b: run C:pay 20000g
# pick 1:a
# you win the trol is now dead
# you find 20G on the dead trool and a cooked steak
# you continu to the floting island
# when you jump on to the island from a near by cliff
# ???:hello?
# a smll white dragon looks at you with a hopful glance
# dragon: O! h-hello...c-could you h-help me?
# dragon: Iv ben stuck hear for months and i think my mother isint comming back.
# you rember the cookrd steak from th dead trool
# A:*kill her* B:*help hear*
# pick 1:b
# you take the stake out of your bag and walk twords her
# dragon: t-thank you
# you put the stake near  her mouth she taks a bite
# you sit down nexto her she puts her claw on your leag
# she moves closer the wormth she has is welcoming
# when she finishies the stake she snuggl up on you and licks your face
# dragon wispers in your ear: Thak you.
# she falls asleep on top of you
# you gro tired falling asleep tn the worm brace
# to be continued
# rcv12 , you have chosen to go left.
# you walk the left path. you see a village in the distance as you approach and a man walks up to you
# ???: Hello adventurer! welcome to my village im the Chief of this village! we have been expecting you  rcv12
# A:[what do you mean expecting me???]  B:[how do you know my name?]  C:*Attack the Chief and take over the village*
# pick 1:c
# you take your sword and impale the chief he falls to his knees
# chief: w-w--why you... now thay....will come...y-YOU!
# YOU KILL THE CHIEF! you have gained control of the village 25 gold round things from the Chief.
# you see the villagers raul all over in a panick
# you ar then serounded by the village gards be for you can re act thay attck killing you!
# you ar now dead

# %%
try:
    string= input("enter words: ").lower()
    f={}
    for i in string:

        f[i]=f.get(0,0)+1
    print("your items",f)
except:
    print("AAAAAAAAAAAAAAAAA")
# Out:
# enter words: sword
# your items {'s': 1, 'w': 1, 'o': 1, 'r': 1, 'd': 1}

# %%
items={}
item =input("Enter item: ")
items= items,item
item =input("Enter item: ")
items= sitems,item
print(items)
