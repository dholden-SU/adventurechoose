# %%
def try_again():
    print("Try again")
def game_over():
    print("Game Over")
def start_adventure():
    print("Your adventure begins. You now have a sword to use along your journey!")
    print("You come across a forked road with two identical paths.")
    print("There is a sign stuck in between the two paths. It reads 'go right for a classic adventure with some strange encounters, go left for a village that you will never forget.")
def alien_scene():
    print("As you go on your way with your new weapon you see a man in a robe. He gestures for you to come closer.")
    print("The man takes off his hood to reveal a large head. He has big grey eyes and green skin, and you realize that he is  an alien")
    print("The alien starts to take something out of his pocket.")
def cave_falling_scene():
    print("As you run away from the alien you slip on a pile of leaves. You fall into the ground and end up in a cave.")
    print("When you stand up you hear a creepy noise from deep inside of the cave.")
def knight_chest_scene():
    print("You walk towards the noise. It gets louder and louder as you get closer to it.")
    print("At the source of the noise there is a man in armor. He has a sword at his belt and starts to turn around.")
    print("The man has a strange accent and seems to be very old. He tells you 'I have been waiting for someone all these years.    Someone to claim a chest.'")
    print("Suddenly you see three chests in the cave.")
    print("The man says they are %s."%(chests))
def silver_chest_poison():
    print("The chest opens and you see a bottle with a purple liquid inside of it. You pop the cork out and begin to drink. The knight says 'Wrong choice this time.'")
    print("You die of poison")      
def blue_chest_powers():
    print("The chest opens with a bright glow. The knight says'You chose well this time.'")
    print("EVenthough the chest is empty you know something is different, but you aren't sure what it is.")
    print("The knight leads you to the exit of the cave, but all you there see is a cliff.")
    print("The knight says trust me and pushes you off of the cliff. As you open your eyes you realize you are hovering mid-air.")
def cursed_chests():
    print("The knight begins to walk back into the cave, and you follow him.")
    print("He teaches you how to control your powers, and shows you what was in the other chests.")
    print("He always tell whoever finds him they are %s "%(chests))
    print("You are told that the other chests are cursed, and that if you chose them you would have died.")
def destroy_chests():
    print("The knight snaps his fingers and you are  back at the pile of leaves that you slipped on.")
    print("You try to fly, but your powers seem to have vanished.")
    print("You see the alien from before the cave standing a few feet away. He starts to take something out of his pocket.")
def take_chests():
    print("Once you have all the chests the knight snaps his fingers.")
    print("Suddenly, you are back at the pile of leaves you slipped on. You try to fly, but your powers seem to have vanished.")
    print("You see the alien from before the cave standing a few feet away. He starts to take something out of his pocket.")

# %%
weapons = ["lazer","crossbow","flamethrower"]
chests = {"Blue":"Super Powers", "Golden":"Wealth", "Silver":"Glory"}
player = input("Enter your charachter's name: ")
choice1 = input("Do you want to play %s (enter yes or no)?"%(player)).lower()
while choice1 == "no":
    print("Please play again")
    choice1 = input("Do you want to play %s (enter yes or no)?"%(player)).lower()
while choice1 != "no" and choice1 != "yes":
    try_again()
    choice1 = input("Do you want to play %s (enter yes or no)?"%(player)).lower()
if choice1 == "yes":
    start_adventure()##
    choice2 = input("Do you want to go left or right?").lower()
while choice2 != "left" and choice2 != "right":
    try_again()
    choice2 = input("Do you want to go left or right? ").lower()
if choice2 == "right":
    print("Good choice %s,you have chosen to go right and now have the option of choosing a new weapon."%(player))
    choice_r1 = input("Which weapon would you like to use %s: "%(weapons)).lower()
    while choice_r1 != "lazer" and choice_r1 != "flamethrower" and choice_r1 != "crossbow":
        choice_r1 = input("Which weapon would you like to use %s: "%(weapons)).lower()
    if choice_r1 == "lazer":
        print("Lazers are always useful")
    if choice_r1 == "crossbow":
        print("I hope you have good aim")
    if choice_r1 == "flamethrower":
        print("Try not to burn yourself")
    alien_scene()##
    choice_r2 = input("Do you want to see what the alien is taking out of his pocket, or turn around and run(type wait or run): ").lower()
    if choice_r2 == "wait":
        print("The alien pulls out a blaster and he kills you.")
        choice_d1 = input("If you want to respawn type respawn, or type end to leave.").lower()
        while choice_d1 != "end" and choice_d1 != "respawn":
            try_again()
            choice_d1 = input("If you want to respawn type respawn, or type end to leave.").lower()
        if choice_d1 == "end":
            game_over()
        if choice_d1 == "respawn":
            choice_r2 = input("Do you want to see what the alien is taking out of his pocket, or turn around and run(type wait or run): ").lower()
    if choice_r2 == "run":
        cave_falling_scene()##
        choice_r3 = input("Do you go see what made the noise, or do you wait for someone to find you(type go or stay): ").lower()
        while choice_r3 != "stay" and choice_r3 != "go":
            try_again()
            choice_r3 = input("Do you go see what made the noise, or do you wait for someone to find you(type go or stay): ").lower()
    while choice_r3 == "stay":
        print("After 13 hours  you are found by a tour group. You give up the adventure and go home.")
        game_over()
        choice_d5 = input("If you want to respawn type respawn, or type end to leave.").lower()
        while choice_d5 != "end" and choice_d5 != "respawn":
            try_again()
            choice_d5 = input("If you want to respawn type respawn, or type end to leave.").lower()
        if choice_d5 == "end":
            game_over()
        if choice_d5 == "respawn":
            choice_r3 = input("Do you go see what made the noise, or do you wait for someone to find you(type go or stay): ").lower()
    if choice_r3 == "go":
        knight_chest_scene()##
        choice_r4 = input("Which chest do you choose?(blue, gold, or silver) ").lower()
    while choice_r4 != "blue" and choice_r4 != "gold" and choice_r4 != "silver":
        try_again()
        choice_r4 = input("Which chest do you choose?(blue, gold, or silver) ").lower()
    while choice_r4 == "gold":
        print("The chest opens it is full of golden coins. As you pick one up to look at, the knight says 'Wrong choice this time', and the cave collapses.")
        game_over()
        choice_d2 = input("If you want to respawn type respawn, or type end to leave.").lower()
        while choice_d2 != "respawn" and choice_d2 != "end":
            try_again()
            choice_d2 = input("If you want to respawn type respawn, or type end to leave.").lower()
        if choice_d2 == "end":
            game_over()
        if choice_d2 == "respawn":
            choice_r4 = input("Which chest do you choose?(blue, gold, or silver) ").lower()
    while choice_r4 == "silver":
        silver_chest_poison()
        game_over()
        choice_d3 = input("If you want to respawn type respawn, or type end to leave.").lower()
        while choice_d3 != "respawn" and choice_d3 != "end":
            try_again()
            choice_d3 = input("If you want to respawn type respawn, or type end to leave.").lower()
        if choice_d3 == "end":
            game_over()
        if choice_d3 == "respawn":
            choice_r4 = input("Which chest do you choose?(blue, gold, or silver) ").lower()
    if choice_r4 == "blue":
        blue_chest_powers()##
        choice_r5 = input("Do you want to stay with the knight or fly away?(type fly or stay): ")
    while choice_r5 != "fly" and choice_r5 != "stay":
        try_again()
        choice_r5 = input("Do you want to stay with the knight or fly away?(type fly or stay): ").lower()
    while choice_r5 == "fly":
        print("You fly away from the cave to try to become a superhero to the nearby villages.")
        game_over()
        choice_d4 = input("If you want to respawn type respawn, or type end to leave.").lower()
        while choice_d4 != "respawn" and choice_d4 != "end":
            try_again()
            choice_d4 = input("If you want to respawn type respawn, or type end to leave.").lower()
        if choice_d4 == "end":
            game_over()
        if choice_d4 == "respawn":
            choice_r5 = input("Do you want to stay with the knight or fly away?(type fly or stay): ").lower()
    if choice_r5 == "stay":
        cursed_chests()##
        choice_r6 = input("You can either destroy the chests with your weapon or take them(type take or destroy): ").lower()
    while choice_r6 != "take" and choice_r6 != "destroy":
        try_again()
        choice_r6 = input("You can either destroy the chests with your weapon or take them(type take or destroy): ").lower()
    if choice_r6 == "destroy" and choice_r1 == "lazer":
        print("Your lazer vaporizes the chests and nothing of them is left.")
        destroy_chests()##
        game_over()
    if choice_r6 == "destroy" and choice_r1 == "flamethrower":
        print("Your flamethrower burns the chests and they turn to ash.")
        destroy_chests()##
        game_over()
    if choice_r6 == "destroy" and choice_r1 == "crossbow":
        print("Your crossbow pierces the chests and the explode.")
        destroy_chests()##
        game_over()
    if choice_r6 == "take":
        take_chests()##
        game_over()
if choice2 == "left":
    items={}
    item =("sword")
    items= items,item
    gc = 25
    sword_dm=15
    df=0
    hi=1
    # "A:[] ","B:[]","c:[]" tlak_action=input("pick 1:").lower()
    ch=1
    while (hi>0):
        print(player,", you have chosen to go left.")  
        print("you walk the left path. you see a village in the distance. As you approach and a man walks up to you" )
        print("???: Hello adventurer! welcome to my village I'm the Chief of this village! we have been expecting you ", player )
        print("A:[what do you mean expecting me???]"," B:[how do you know my name?]"," C:*Attack the Chief and take over the village*")
        tlak_action=input("pick 1:").lower()
        if (tlak_action == 'a'):
            
            print(player,": What do you mean expecting me!?!")
            print("Chief: there's no time. Take this, arm yourself and help us. They're coming!!! find me when your done")
            print("he puts 25 gold coins (G) in your hand and runs off...")
            print("A:[explore the village] ","B:[leave the village]")
            
            tlak_action=input("pick 1:").lower()
            if (tlak_action == 'a'):
                while True:
                    print("you find a village map and see 3 locations to buy supplies")
                    while True:
                        print("A: smithery, B: armory, C: potions brewery d:Town hall")
                        tlak_action=input("pick 1:").lower()
                        if (tlak_action == 'a'):
                                print("in the smitherey you see a merchant")
                                print("smith: Welcome to my shop stranger, feel free to look around.")
                                print("you look at all the items")
                                while True:
                                    print("A:  weak bow with 5 arrows 5g B: swordbuff gem flame 20G c:leave")
                                    print("you have %d G"%(gc))
                                    tlak_action=input("pick 1:").lower()
                                    if (tlak_action == 'a'):
                                        if gc>=5:
                                            gc= gc-5
                                            print("you purchase a bow and 5 arrows")
                                            arrows=5
                                            item =("bow")
                                            items= items,item
                                            bow_dm=10
                                        else:
                                            print("you dont have enough")
                                    elif (tlak_action == 'b'):
                                            if (gc>=20):
                                                gc=gc-20
                                                print("you purchase a flamegem")
                                                sword_dm=sword_dm+10
                                            else:
                                                print("you dont have enough")
                                    elif(tlak_action == 'c'):
                                            print("you leave the shop")
                                            break
                        elif (tlak_action == 'b'):
                            print("in the armory you see a merchant")
                            print("merchant: Welcome to my shop stranger, feel free to look around.")
                            print("you look at all the items")
                            while True:
                                print("A: light leather underarmer 10df 5G B: heavy metal overarmer 20 c:leave")
                                print("you have %d G"%(gc))
                                tlak_action=input("pick 1:").lower()
                                if (tlak_action == 'a'):                    
                                    if gc>=5:
                                        gc= gc-5
                                        print("you purchased light leather underarmer")
                                        df=df+10
                                        item =("leverarmeru")
                                        items= items,item
                                    else:
                                         print("you dont have enough")
                                                #flame gem
                                elif (tlak_action == 'b'):
                                    if (gc>=20):
                                        gc=gc-20
                                        print("you purchase metal armer")
                                        df=df+25
                                        item =("mettlearmer")
                                        items= items,item
                                    else:
                                        print("you dont have enough")
                                elif(tlak_action == 'c'):
                                    print("you leave the shop")
                                    break
                        elif (tlak_action == 'c'):
                            print("in the potions brewery you see a merchant")
                            print("merchant: Welcome to my shop stranger, feel free to look around.")
                            print("you look at all the items")
                            while True:
                                print("A: moonshard potion 5G B: soul potion 20G c:leave")
                                print("you have %d G"%(gc))
                                tlak_action=input("pick 1:").lower()
                                if (tlak_action == 'a'):
                                    if gc>=5:
                                        gc= gc-5
                                        print("you purchased moonshard potion")
                                        item =("moonshardpotion")
                                        items= items,item
                                    else:
                                        print("you dont have enough")
                                                #flame gem
                                elif (tlak_action == 'b'):
                                    if (gc>=20):
                                        gc=gc-20
                                        print("you purchase soul potion")
                                        item =("solepotion")
                                        items= items,item
                                    else:
                                        print("you dont have enough")
                                elif(tlak_action == 'c'):
                                    print("you leave the shop")
                                    break
                        elif (tlak_action == 'd'):
                            print("TO TOWN HALL!! here you will meet the Chief")
                            print("as you enter town hall the Chief sees you")
                            print ("Chief: ah there you are so here's a horse now go to that oasis I will explain everything when I'm there")
                            print("Chief: but if something happens you must find the floating island and defeat the dragon!")
                            print("he points to a small oasis in the distance you can see mangos...MANGOS!!!")
                            print("A: *go* B: [what i dont even know you!]")
                            tlak_action=input("pick 1:").lower()
                            if (tlak_action == 'a'):
                                print("you go out on your horse")
                                print("while you're waiting the village gets hit by a huge fire ball and is destroyed")
                                print("you continue to search for the floating island to defeat some dragon!")
                                print("on your way a troll blocks your path")
                                print("A:fight b: run C:pay 2,000g")
                                tlak_action=input("pick 1:").lower()
                                if (tlak_action == 'a'):
                                    print("you win the troll is now dead")
                                    gc=gc+20
                                    print("you find 20G on the dead troll and a cooked steak")
                                    print("you continue to the floating island")
                                    print("when you jump on to the island from a near by cliff")
                                    print("???:hello?")
                                    print("a small white dragon looks at you with a hopeful glance")
                                    print("dragon: Oh! h-hello...c-could you h-help me?")
                                    print("dragon: I've been stuck here for months and I think my mother is not coming back.")
                                    print("you remember the cooked steak from the dead troll")
                                    print("A:*kill her* B:*help hear*")
                                    tlak_action=input("pick 1:").lower()
                                    if (tlak_action == 'a'):
                                        print("you unsheathe your sword")
                                        print("dragon looks scared")
                                        print("dragon: w-what are you donig... p-please D-DONT!")
                                        print("you walk towards the dragon she starts crying and shaking")
                                        print("dragon: SOMEBODY ANYBODY PLEASE HELP!")
                                        print(player,": hold still it will all be over soon")
                                        print("she curls up into a ball")
                                        print("dragon: p-please.")
                                        print("you chop off her head and put it into your bag")
                                        print("the cold dead lifeless body is splattering blood everywhere")
                                        print("to be continued")
                                        break
                                        break
                                        break
                                        hi=-1
                                        while True:
                                            gc=gc
                                    elif (tlak_action == 'b'):
                                        print("you take the steak out of your bag and walk towards her")
                                        print("dragon: t-thank you")
                                        print("you put the steak near her mouth she takes a bite")
                                        print("you sit down next to her she puts her claw on your leg")
                                        print("she moves closer, the warmth she has is welcoming")
                                        print("when she finishes the steak she snuggles up on you and licks your face")
                                        print("dragon whispers: Thank you.")
                                        print("she falls asleep on you")
                                        print("you grow tired, falling asleep in the warm embrace")
                                        print("to be continued")
                                        break
                                        break
                                        break
                                        hi=-1
                                        while True:
                                            gc=gc
                                elif (tlak_action == 'b'):
                                    print("the troll jumps on you and then eats you")
                                    print ("you have died your story ends here")
                                    break
                                    break
                                    break
                                    hi=-1
                                    while True:
                                        gc=gc
                                elif (tlak_action == 'c'):
                                    print("the troll jumps on you and then eats you")
                                    print ("you have died your story ends here")
                                    break
                                    break
                                    break
                                    hi=-1
                                    while True:
                                        gc=gc
                            elif (tlak_action == 'b'):
                                print(player,": what I dont even know you!")
                                print("Chief: I will explain everthing to you at the oasis.")
                                print(player,": NO I need to know what is going on right now or I'm not helping!")
                                print("Chief: fine, fine. we have reason to believe that the gods have sent us a warrior-")
                                print("- you. you're here to help us defeat all the evil forces of this world and.....")
                                print("the village gets hit by a huge fire ball and is destroyed with you in it")
                                print ("you have died your story ends here")
                                break
                                break
                                break
                                hi=-1
                                while True:
                                    gc=gc
                        else:
                            print("nope")
                        #break
                    break
                            
                    
            elif(tlak_action == 'b'):
                print("the gaurds see you and mistake you for a thief they attack you and kill you")
                print("you are dead your story ends here") 
                break
                while True:
                    gc=gc
        elif (tlak_action == 'b'):
            print(player,": how do you know my name?")
            print("Chief: there's no time. Take this, arm yourself and help us. They're coming!!! Find me when your done")
            print("he puts 25 gold coins (G) in your hand and runs off...")
            print("A:[explore the village] ","B:[leave the village]")
            
            tlak_action=input("pick 1:").lower()
            if (tlak_action == 'a'):
                while True:
                    print("you find a village map and see 3 locations to buy supplies")
                    while True:
                        print("A: smithery, B: armory, C: potions brewery d:Town hall")
                        tlak_action=input("pick 1:").lower()
                        if (tlak_action == 'a'):
                                print("in the smitherey you see a merchant")
                                print("smith: Welcome to my shop stranger, feel free to look around.")
                                print("you look at all the items")
                                while True:
                                    print("A:  weak bow with 5 arrows 5g B: swordbuff gem flame 20G c:leave")
                                    print("you have %d G"%(gc))
                                    tlak_action=input("pick 1:").lower()
                                    if (tlak_action == 'a'):
                                        if gc>=5:
                                            gc= gc-5
                                            print("you purchase a bow and 5 arrows")
                                            arrows=5
                                            item =("bow")
                                            items= items,item
                                            bow_dm=10
                                        else:
                                            print("you dont have enough")
                                    elif (tlak_action == 'b'):
                                            if (gc>=20):
                                                gc=gc-20
                                                print("you purchase a flamegem")
                                                sword_dm=sword_dm+10
                                            else:
                                                print("you dont have enough")
                                    elif(tlak_action == 'c'):
                                            print("you leave the shop")
                                            break
                        elif (tlak_action == 'b'):
                            print("in the armory you see a merchant")
                            print("merchant: Welcome to my shop stranger, feel free to look around.")
                            print("you look at all the items")
                            while True:
                                print("A: light leather underarmer 10df 5G B: heavy metal overarmer 20 c:leave")
                                print("you have %d G"%(gc))
                                tlak_action=input("pick 1:").lower()
                                if (tlak_action == 'a'):                    
                                    if gc>=5:
                                        gc= gc-5
                                        print("you purchased light leather underarmer")
                                        df=df+10
                                        item =("leverarmeru")
                                        items= items,item
                                    else:
                                         print("you dont have enough")
                                                #flame gem
                                elif (tlak_action == 'b'):
                                    if (gc>=20):
                                        gc=gc-20
                                        print("you purchase metal armer")
                                        df=df+25
                                        item =("mettlearmer")
                                        items= items,item
                                    else:
                                        print("you dont have enough")
                                elif(tlak_action == 'c'):
                                    print("you leave the shop")
                                    break
                        elif (tlak_action == 'c'):
                            print("in the potions brewery you see a merchant")
                            print("merchant: Welcome to my shop stranger, feel free to look around.")
                            print("you look at all the items")
                            while True:
                                print("A: moonshard potion 5G B: soul potion 20G c:leave")
                                print("you have %d G"%(gc))
                                tlak_action=input("pick 1:").lower()
                                if (tlak_action == 'a'):
                                    if gc>=5:
                                        gc= gc-5
                                        print("you purchased moonshard potion")
                                        item =("moonshardpotion")
                                        items= items,item
                                    else:
                                        print("you dont have enough")
                                                #flame gem
                                elif (tlak_action == 'b'):
                                    if (gc>=20):
                                        gc=gc-20
                                        print("you purchase soul potion")
                                        item =("solepotion")
                                        items= items,item
                                    else:
                                        print("you dont have enough")
                                elif(tlak_action == 'c'):
                                    print("you leave the shop")
                                    break
                        elif (tlak_action == 'd'):
                            print("TO TOWN HALL!! here you will meet the Chief")
                            print("as you enter town hall the Chief sees you")
                            print ("Chief: ah there you are so here's a horse now go to that oasis I will explain everything when I'm there")
                            print("Chief: but if something happens you must find the floating island and defeat the dragon!")
                            print("he points to a small oasis in the distance you can see mangos...MANGOS!!!")
                            print("A: *go* B: [what i dont even know you!]")
                            tlak_action=input("pick 1:").lower()
                            if (tlak_action == 'a'):
                                print("you go out on your horse")
                                print("while you're waiting the village gets hit by a huge fire ball and is destroyed")
                                print("you continue to search for the floating island to defeat some dragon!")
                                print("on your way a troll blocks your path")
                                print("A:fight b: run C:pay 2,000g")
                                tlak_action=input("pick 1:").lower()
                                if (tlak_action == 'a'):
                                    print("you win the troll is now dead")
                                    gc=gc+20
                                    print("you find 20G on the dead troll and a cooked steak")
                                    print("you continue to the floating island")
                                    print("when you jump on to the island from a near by cliff")
                                    print("???:hello?")
                                    print("a small white dragon looks at you with a hopeful glance")
                                    print("dragon: Oh! h-hello...c-could you h-help me?")
                                    print("dragon: I've been stuck here for months and I think my mother is not coming back.")
                                    print("you remember the cooked steak from the dead troll")
                                    print("A:*kill her* B:*help hear*")
                                    tlak_action=input("pick 1:").lower()
                                    if (tlak_action == 'a'):
                                        print("you unsheathe your sword")
                                        print("dragon looks scared")
                                        print("dragon: w-what are you donig... p-please D-DONT!")
                                        print("you walk towards the dragon she starts crying and shaking")
                                        print("dragon: SOMEBODY ANYBODY PLEASE HELP!")
                                        print(player,": hold still it will all be over soon")
                                        print("she curls up into a ball")
                                        print("dragon: p-please.")
                                        print("you chop off her head and put it into your bag")
                                        print("the cold dead lifeless body is splattering blood everywhere")
                                        print("to be continued")
                                        break
                                        break
                                        break
                                        hi=-1
                                        while True:
                                            gc=gc
                                    elif (tlak_action == 'b'):
                                        print("you take the steak out of your bag and walk towards her")
                                        print("dragon: t-thank you")
                                        print("you put the steak near her mouth she takes a bite")
                                        print("you sit down next to her she puts her claw on your leg")
                                        print("she moves closer, the warmth she has is welcoming")
                                        print("when she finishes the steak she snuggles up on you and licks your face")
                                        print("dragon whispers: Thank you.")
                                        print("she falls asleep on you")
                                        print("you grow tired, falling asleep in the warm embrace")
                                        print("to be continued")
                                        break
                                        break
                                        break
                                        hi=-1
                                        while True:
                                            gc=gc
                                elif (tlak_action == 'b'):
                                    print("the troll jumps on you and then eats you")
                                    print ("you have died your story ends here")
                                    break
                                    break
                                    break
                                    hi=-1
                                    while True:
                                        gc=gc
                                elif (tlak_action == 'c'):
                                    print("the troll jumps on you and then eats you")
                                    print ("you have died your story ends here")
                                    break
                                    break
                                    break
                                    hi=-1
                                    while True:
                                        gc=gc
                            elif (tlak_action == 'b'):
                                print(player,": what I dont even know you!")
                                print("Chief: I will explain everthing to you at the oasis.")
                                print(player,": NO I need to know what is going on right now or I'm not helping!")
                                print("Chief: fine, fine. we have reason to believe that the gods have sent us a warrior-")
                                print("- you. you're here to help us defeat all the evil forces of this world and.....")
                                print("the village gets hit by a huge fire ball and is destroyed with you in it")
                                print ("you have died your story ends here")
                                break
                                break
                                break
                                hi=-1
                                while True:
                                    gc=gc
                        else:
                            print("nope")
                        #break
                    break
                            
            
                            
                    
            elif(tlak_action == 'b'):
                print("the gaurds see you and mistake you for a thief they attack you and kill you")
                print("you are dead your story ends here") 
                break
                while True:
                    gc=gc
        elif (tlak_action == 'c'):
            print("you take your sword and impale the Chief he falls to his knees")
            print("Chief: w-w--why you... now they....will come...y-YOU!")
            print("YOU KILLED THE CHIEF! you have gained control of the village. You take 25 gold round things from the Chief's dead body.")
            print("you see the villagers ran all over in a panic")
            print("you are then surounded by the village gaurds before you can react they attack, killing you!")
            print ("you are now dead your story ends here.")
            break
        else:
            print("time warp")
# Out:
# Enter your charachter's name: doug
# Do you want to play doug  (enter yes or no)?yes
# Your adventure begins. You now have a sword to use along your journey!
# You come across a forked road with two identical paths.
# There is a sign stuck in between the two paths. It reads 'go right for a classic adventure with some strange encounters, go left for a village that you will never forget.
# Do you want to go left or right?right
# Good choice doug ,you have chosen to go right and now have the option of choosing a new weapon.
